# %%
import pandas as pd
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It wad awful'], 'Sue': ['Pretty', 'Bland']})
# Out:
#             Bob     Sue
# 0   I liked it.  Pretty
# 1  It wad awful   Bland

# %%
pd.DataFrame({
    'A':['a','ab','aa'],
    'B':['b','ba','bb']},
    index=['resultA', 'resultB','resultC'])
# Out:
#           A   B
# resultA   a   b
# resultB  ab  ba
# resultC  aa  bb

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df = pd.read_csv('data.csv')

# %%
df.shape
# Out:
# (3, 3)

# %%
df.head()
# Out:
#    title     name  age
# 0    abc    test1   17
# 1   abcd   test12   18
# 2  abcde  test123   19
